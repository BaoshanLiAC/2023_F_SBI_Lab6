# %% [markdown]
# # Feature Engineering

# %% [markdown]
# #### Import the required libraries

# %%
# NumPy for numerical computing
import numpy as np

# Pandas for DataFrames
import pandas as pd
pd.set_option('display.max_columns', 100)

# Matplotlib for visualization
from matplotlib import pyplot as plt

# display plots in the notebook
# %matplotlib inline 

# Seaborn for visualization
import seaborn as sns

# %% [markdown]
# #### Import the cleaned dataset

# %%
# Load cleaned dataset from the previous lecture
df = pd.read_csv('cleaned_df.csv')
df.head(2)
# Out:
#     price  year_sold  property_tax  insurance  beds  baths  sqft  year_built  \
# 0  295850       2013           234         81     1      1   584        2013
# 1  216500       2006           169         51     1      1   612        1965
#
#    lot_size  basement property_type
# 0         0       0.0         Condo
# 1         0       1.0         Condo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1883 entries, 0 to 1882
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          1883 non-null   int64
#  1   year_sold      1883 non-null   int64
#  2   property_tax   1883 non-null   int64
#  3   insurance      1883 non-null   int64
#  4   beds           1883 non-null   int64
#  5   baths          1883 non-null   int64
#  6   sqft           1883 non-null   int64
#  7   year_built     1883 non-null   int64
#  8   lot_size       1883 non-null   int64
#  9   basement       1883 non-null   float64
#  10  property_type  1883 non-null   object
# dtypes: float64(1), int64(9), object(1)
# memory usage: 161.9+ KB

# %% [markdown]
# ## I. Domain Knowledge

# %% [markdown]
# #### A. Popular Properties
#
# 2 bedroom and 2 bathroom properties are especially popular for investors. Let's create an indicator variable just for properties with 2 beds and 2 baths.

# %%
# Build your code step by step
#((df.beds == 2) & (df.baths == 2))
# ((df.beds == 2) & (df.baths == 2)).astype(int)

# %%
# Create indicator variable for properties with 2 beds and 2 baths
df['popular'] = ((df.beds == 2) & (df.baths == 2)).astype(int)

# %%
# Check how many propoerties have 2 baths and 2 beds 
df.popular.value_counts()
# Out:
# 0    1705
# 1     178
# Name: popular, dtype: int64

# %% [markdown]
# #### B. Housing Market Recession
#
# We are modeling housing prices in the United States, it's important to consider the housing market recession around 2008. According to data from Zillow, the lowest housing prices were from 2010 to end of 2013.
#
# <br>
# Create an indicator feature **recession**
#
# Here's how:
# * Your first condition `year_sold >= 2010`
# * Your second condition `year_sold <= 2013`
# * Combine the two conditions with an `&` operator
# * Convert the resulting data to `int` type.

# %%
# Create a new variable recession
df['recession']=((df.year_sold >= 2010) & (df.year_sold <= 2013)).astype(int)

# %%
# Check how many propoerties were sold during recession period 
df.recession.value_counts()
# Out:
# 0    1387
# 1     496
# Name: recession, dtype: int64

# %%
fd = df[['year_sold','recession']]
fd.head(8)
# Out:
#    year_sold  recession
# 0       2013          1
# 1       2006          0
# 2       2012          1
# 3       2005          0
# 4       2002          0
# 5       2004          0
# 6       2011          1
# 7       2005          0

# %% [markdown]
# ## II. Interaction Features

# %% [markdown]
# In the first step, you engineered features from domain knowledge. interaction features can be products, sums, or differences between two features.

# %% [markdown]
# #### A. Property Age
#
# We have the features `year_sold` and the `year_built`. let's create a new feature `property_age`

# %%
df['property_age'] = df.year_sold - df.year_built

# %%
type(df.property_age)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Do a quick sanity check on that feature. Run `df.describe()` and check the stats for the feature `property_age`

# %%
# Do you see any error?
df.describe()
# Out:
#                price    year_sold  property_tax    insurance         beds  \
# count    1883.000000  1883.000000   1883.000000  1883.000000  1883.000000
# mean   422839.807754  2007.111524    466.777483   140.454063     3.420605
# std    151462.593276     5.196898    231.656645    72.929765     1.068554
# min    200000.000000  1993.000000     88.000000    30.000000     1.000000
# 25%    300000.000000  2004.000000    320.000000    94.000000     3.000000
# 50%    392000.000000  2007.000000    426.000000   125.000000     3.000000
# 75%    525000.000000  2011.000000    569.000000   169.000000     4.000000
# max    800000.000000  2016.000000   4508.000000  1374.000000     5.000000
#
#              baths         sqft   year_built      lot_size     basement  \
# count  1883.000000  1883.000000  1883.000000  1.883000e+03  1883.000000
# mean      2.579926  2329.398832  1982.963887  1.339262e+04     0.879979
# std       0.945576  1336.991858    20.295945  4.494930e+04     0.325073
# min       1.000000   500.000000  1880.000000  0.000000e+00     0.000000
# 25%       2.000000  1345.000000  1970.000000  1.542000e+03     1.000000
# 50%       3.000000  1907.000000  1986.000000  6.098000e+03     1.000000
# 75%       3.000000  3005.000000  2000.000000  1.176100e+04     1.000000
# max       6.000000  8450.000000  2015.000000  1.220551e+06     1.000000
#
#            popular    recession  property_age
# count  1883.000000  1883.000000   1883.000000
# mean      0.094530     0.263409     24.147637
# std       0.292642     0.440600     21.167604
# min       0.000000     0.000000     -8.000000
# 25%       0.000000     0.000000      6.000000
# 50%       0.000000     0.000000     20.000000
# 75%       0.000000     1.000000     38.000000
# max       1.000000     1.000000    114.000000

# %%
# Check number of observations with 'property_age' < 0
(df.property_age < 0).sum()
# Out:
# 19

# %% [markdown]
# On second thought, this could be an error or that some homeowners buy houses before the construction company builts them. But for the purpose of this project we will remove these observations.
#
# We'll do a quick ad-hoc data cleaning and remove these observations from our dataset.

# %% [markdown]
# #### Remove observations where `property_age` is less than 0.
# * Keep only observations where `property_age` is 0 and above.

# %%
# Print df shape before
print(df.shape)

# Remove rows where property_age is less than 0
df = df[df.property_age >= 0]

# Print number of rows in remaining dataframe
print(df.shape)
# Out:
# (1882, 15)
# (1863, 15)

# %%
df.corr()
# Out:
# C:\Users\Samuel\AppData\Local\Temp\ipykernel_24484\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  price  year_sold  property_tax  insurance      beds  \
# price         1.000000   0.108782      0.535148   0.532947  0.384046
# year_sold     0.108782   1.000000     -0.257703  -0.254706 -0.174081
# property_tax  0.535148  -0.257703      1.000000   0.984724  0.547643
# insurance     0.532947  -0.254706      0.984724   1.000000  0.485776
# beds          0.384046  -0.174081      0.547643   0.485776  1.000000
# baths         0.389375  -0.132110      0.525776   0.475430  0.644572
# sqft          0.469573  -0.236190      0.660264   0.594049  0.691039
# year_built    0.033138  -0.043301     -0.046504  -0.109521 -0.011844
# lot_size      0.130558  -0.048207      0.165800   0.146579  0.164399
# basement      0.109479  -0.070075      0.184327   0.138771  0.414633
# popular      -0.147166   0.068880     -0.207048  -0.173698 -0.429675
# recession    -0.023845   0.510217     -0.114896  -0.114483 -0.067287
# property_age -0.005066   0.287029     -0.018680   0.042478 -0.031383
#
#                  baths      sqft  year_built  lot_size  basement   popular  \
# price         0.389375  0.469573    0.033138  0.130558  0.109479 -0.147166
# year_sold    -0.132110 -0.236190   -0.043301 -0.048207 -0.070075  0.068880
# property_tax  0.525776  0.660264   -0.046504  0.165800  0.184327 -0.207048
# insurance     0.475430  0.594049   -0.109521  0.146579  0.138771 -0.173698
# beds          0.644572  0.691039   -0.011844  0.164399  0.414633 -0.429675
# baths         1.000000  0.682060    0.206141  0.132976  0.344108 -0.198216
# sqft          0.682060  1.000000    0.254589  0.246016  0.270308 -0.268666
# year_built    0.206141  0.254589    1.000000  0.000068  0.008846  0.100235
# lot_size      0.132976  0.246016    0.000068  1.000000  0.011123 -0.078069
# basement      0.344108  0.270308    0.008846  0.011123  1.000000 -0.199046
# popular      -0.198216 -0.268666    0.100235 -0.078069 -0.199046  1.000000
# recession    -0.053111 -0.073216    0.031012 -0.005772 -0.046260  0.082885
# property_age -0.230087 -0.302093   -0.969452 -0.011900 -0.025686 -0.079196
#
#               recession  property_age
# price         -0.023845     -0.005066
# year_sold      0.510217      0.287029
# property_tax  -0.114896     -0.018680
# insurance     -0.114483      0.042478
# beds          -0.067287     -0.031383
# baths         -0.053111     -0.230087
# sqft          -0.073216     -0.302093
# year_built     0.031012     -0.969452
# lot_size      -0.005772     -0.011900
# basement      -0.046260     -0.025686
# popular        0.082885     -0.079196
# recession      1.000000      0.095530
# property_age   0.095530      1.000000

# %% [markdown]
# ### III. Drop Redundant Features
#
# Beacuse we created a new feature `property_age` using features `year_built` and `year_sold`. We can drop those two features.
#
# **Remove features 'year_built' and 'year_sold'**
# * Use Pandas's `.drop()` function.
# * Remember to set `axis=1` because you are dropping columns.
# * Remember to do 'inplace=True'.

# %%
# Drop 'year_built' and 'year_sold' from the dataset
df.drop(['year_built', 'year_sold'], axis=1, inplace=True)
df.head()
# Out:
#    Unnamed: 0   price  property_tax  insurance  beds  baths  sqft  lot_size  \
# 0           0  295850           234         81     1      1   584         0
# 1           1  216500           169         51     1      1   612         0
# 2           2  279900           216         74     1      1   615         0
# 3           3  379900           265         92     1      1   618     33541
# 4           4  340000            88         30     1      1   634         0
#
#    basement property_type  popular  recession
# 0       0.0         Condo        0          1
# 1       1.0         Condo        0          0
# 2       0.0         Condo        0          1
# 3       0.0         Condo        0          0
# 4       0.0         Condo        0          0

# %% [markdown]
# ### Save the final dataset

# %% [markdown]
# We will save this dataset and train our model on it.

# %%
# Save the data as 'final.csv'
df.to_csv('final.csv', index=None)
